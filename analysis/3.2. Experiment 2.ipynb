# %% [markdown]
# ---

# %%
from pathlib import Path

path = Path().absolute()

# %%
cd ../
# Out:
# c:\Users\c10nGp4\OneDrive\Documents\GitHub\imbalance-multi-classification

# %%
import pickle
import time

from sklearn.pipeline import Pipeline

# %% [markdown]
# ---

# %% [markdown]
# ### Load Data
# ---

# %%
import pandas as pd

# Load training set
training_set_df = pd.read_csv(path / "assets/datasets/training-set-1.csv", delimiter=";")

# Get X and y from dataset
X_train = list(training_set_df["texts"])
y_train = list(training_set_df["targets"])

# %% [markdown]
# ### Data Preparation
# ---

# %% [markdown]
# #### Text Preprocessing

# %%
from pipeline.text_cleaning import TextCleaning
from pipeline.tokenize_mwt_pos_lemma import TokenizeMWTPOSLemma

text_preprocessing_pipeline: Pipeline = Pipeline([
    ("text_cleaning", TextCleaning()),
    ("tokenize_mwt_pos_lemma", TokenizeMWTPOSLemma())
])

X_train = text_preprocessing_pipeline.transform(X_train)
# Out:
# 2023-06-12 08:45:56 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# 2023-06-12 08:45:56 INFO: DOWNLOAD STANZA MODEL
# 2023-06-12 08:45:56 INFO: LOAD STANZA PIPELINE: tokenize,mwt,pos,lemma
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json:   0%|   …
# 2023-06-12 08:45:56 INFO: Loading these models for language: id (Indonesian):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | gsd     |
# | mwt       | gsd     |
# | pos       | gsd     |
# | lemma     | gsd     |
# =======================
#
# 2023-06-12 08:45:56 INFO: Using device: cuda
# 2023-06-12 08:45:56 INFO: Loading: tokenize
# 2023-06-12 08:45:58 INFO: Loading: mwt
# 2023-06-12 08:45:58 INFO: Loading: pos
# 2023-06-12 08:45:58 INFO: Loading: lemma
# 2023-06-12 08:45:58 INFO: Done loading processors!
# 2023-06-12 08:45:58 INFO: TEXT CLEANING
# 2023-06-12 08:46:00 INFO: TOKENIZE, MWT, POS, LEMMA

# %% [markdown]
# #### Feature Selection

# %%
from pipeline.data.stopwords import STOPWORDS
from pipeline.pos_filter import POSFilter
from pipeline.stopword_removal import StopWordRemoval
from pipeline.document_transformer import DocumentTransformer

pos_filter_hyperparameters = {
    "pos": ("ADJ","ADV","NOUN","PART","VERB")
}

stopword_removal_hyperparameters = {
    "stopwords": STOPWORDS
}

document_transformer_hyperparameters = {
    "feat_attrs": ["lemma","upos"]
}

feature_selection_pipeline: Pipeline = Pipeline([
    ("pos_filter", POSFilter(**pos_filter_hyperparameters, verbose=0)),
    ("stopword_removal", StopWordRemoval(**stopword_removal_hyperparameters, verbose=0)),
    ("document_transformer", DocumentTransformer(**document_transformer_hyperparameters, verbose=0))
])

X_train = feature_selection_pipeline.transform(X_train)

# %% [markdown]
# ### Hyper-parameters tuning
# ---

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC

def fun(arg):
    return arg

tfidfvectorizer_hyperparameters = {
    "encoding": "ascii",
    "decode_error": "ignore",
    "strip_accents": "ascii",
    "preprocessor": fun,
    "tokenizer": fun,
    "analyzer": "word",
    "token_pattern": None,
    "ngram_range": (1, 1),
    "min_df": 1,
    "max_df": 1.0,
    "norm": "l2",
    "sublinear_tf": False,
}

linearsvc_hyperparameters = {
    "loss": "squared_hinge",
    "dual": False,
    "multi_class": "ovr",
    "max_iter": 1000000,
    "random_state": 42,
    "penalty": "l2",
    "tol": 0.0001,
    "C": 1.0,
    "fit_intercept": True,
    "intercept_scaling": 1.0,
    "class_weight": "balanced",
}

classification_pipeline: Pipeline = Pipeline([
    ("tfidfvectorizer", TfidfVectorizer(**tfidfvectorizer_hyperparameters)),
    ("linearsvc", LinearSVC(**linearsvc_hyperparameters))
])

# %%
import warnings

from sklearn.exceptions import ConvergenceWarning
from sklearn.metrics import make_scorer, accuracy_score, matthews_corrcoef
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedShuffleSplit

warnings.filterwarnings("ignore", category=ConvergenceWarning)
# warnings.filterwarnings("default", category=ConvergenceWarning)

param_distributions = [
    {"tfidfvectorizer__ngram_range": ((1, 1), (1, 2), (2, 2), (1, 3), (2, 3), (3, 3))},
    {"tfidfvectorizer__min_df": (1, 3, 5, 10, 25)},
    {"tfidfvectorizer__max_df": (0.001, 0.01, 0.1, 1.0)},
    {"tfidfvectorizer__norm": (None, "l1", "l2")},
    {"tfidfvectorizer__sublinear_tf": (True, False)},
    {"linearsvc__penalty": ("l1", "l2")},
    {"linearsvc__C": (0.001, 0.01, 0.1, 1, 10, 100, 1000)},
    {
        "linearsvc__fit_intercept": (True,),
        "linearsvc__intercept_scaling": (0.001, 0.01, 0.1, 1, 10, 100, 1000)
    },
    {"linearsvc__fit_intercept": (False,)},
    {"linearsvc__class_weight": (None, "balanced")}
]

n_iter = 10000
n_splits = 5
train_size = 0.8
n_jobs = 1
verbose = 2

randomized_search = RandomizedSearchCV(
    estimator=classification_pipeline,
    param_distributions=param_distributions,
    n_iter=n_iter,
    scoring=make_scorer(matthews_corrcoef),
    n_jobs=n_jobs,
    cv=StratifiedShuffleSplit(n_splits=n_splits, train_size=train_size, random_state=42),
    verbose=verbose,
    random_state=42
)

t0 = time.time()
randomized_search.fit(X_train, y_train)
estimation = time.time() - t0

cv_results_df = pd.DataFrame(randomized_search.cv_results_)
cv_results_df = cv_results_df.rename(lambda col_name: col_name.split("__")[-1] if "param_" in col_name else col_name, axis="columns")

col_names = [
    "ngram_range","min_df","max_df","norm","sublinear_tf",
    "penalty","C","fit_intercept","intercept_scaling","class_weight",
    "split0_test_score","split1_test_score","split2_test_score","split3_test_score","split4_test_score","mean_test_score",
    "mean_fit_time",
    "rank_test_score"
]

cv_results_df = cv_results_df.reindex(columns=col_names)
cv_results_df = cv_results_df.fillna("None")
cv_results_df.to_csv(path / "assets/experiments/experiment_2_cv_results.csv", sep=";", index=False)
# Out:
# c:\Users\c10nGp4\anaconda3\envs\imbalance-multi-classification\lib\site-packages\sklearn\model_selection\_search.py:305: UserWarning: The total space of parameters 39 is smaller than n_iter=10000. Running 39 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 5 folds for each of 39 candidates, totalling 195 fits
# [CV] END ................tfidfvectorizer__ngram_range=(1, 1); total time=   0.2s
# [CV] END ................tfidfvectorizer__ngram_range=(1, 1); total time=   0.1s
# [CV] END ................tfidfvectorizer__ngram_range=(1, 1); total time=   0.1s
# [CV] END ................tfidfvectorizer__ngram_range=(1, 1); total time=   0.1s
# [CV] END ................tfidfvectorizer__ngram_range=(1, 1); total time=   0.1s
# [CV] END ................tfidfvectorizer__ngram_range=(1, 2); total time=   0.4s
# [CV] END ................tfidfvectorizer__ngram_range=(1, 2); total time=   0.5s
# [CV] END ................tfidfvectorizer__ngram_range=(1, 2); total time=   0.7s
# [CV] END ................tfidfvectorizer__ngram_range=(1, 2); total time=   0.8s
# [CV] END ................tfidfvectorizer__ngram_range=(1, 2); total time=   0.7s
# [CV] END ................tfidfvectorizer__ngram_range=(2, 2); total time=   0.7s
# [CV] END ................tfidfvectorizer__ngram_range=(2, 2); total time=   0.3s
# [CV] END ................tfidfvectorizer__ngram_range=(2, 2); total time=   0.6s
# [CV] END ................tfidfvectorizer__ngram_range=(2, 2); total time=   0.5s
# [CV] END ................tfidfvectorizer__ngram_range=(2, 2); total time=   0.5s
# [CV] END ................tfidfvectorizer__ngram_range=(1, 3); total time=   0.7s
# [CV] END ................tfidfvectorizer__ngram_range=(1, 3); total time=   0.6s
# [CV] END ................tfidfvectorizer__ngram_range=(1, 3); total time=   0.5s
# [CV] END ................tfidfvectorizer__ngram_range=(1, 3); total time=   0.5s
# [CV] END ................tfidfvectorizer__ngram_range=(1, 3); total time=   0.5s
# [CV] END ................tfidfvectorizer__ngram_range=(2, 3); total time=   0.3s
# [CV] END ................tfidfvectorizer__ngram_range=(2, 3); total time=   0.3s
# [CV] END ................tfidfvectorizer__ngram_range=(2, 3); total time=   0.3s
# [CV] END ................tfidfvectorizer__ngram_range=(2, 3); total time=   0.3s
# [CV] END ................tfidfvectorizer__ngram_range=(2, 3); total time=   0.3s
# [CV] END ................tfidfvectorizer__ngram_range=(3, 3); total time=   0.2s
# [CV] END ................tfidfvectorizer__ngram_range=(3, 3); total time=   0.1s
# [CV] END ................tfidfvectorizer__ngram_range=(3, 3); total time=   0.1s
# [CV] END ................tfidfvectorizer__ngram_range=(3, 3); total time=   0.1s
# [CV] END ................tfidfvectorizer__ngram_range=(3, 3); total time=   0.1s
# [CV] END ..........................tfidfvectorizer__min_df=1; total time=   0.1s
# [CV] END ..........................tfidfvectorizer__min_df=1; total time=   0.1s
# [CV] END ..........................tfidfvectorizer__min_df=1; total time=   0.1s
# [CV] END ..........................tfidfvectorizer__min_df=1; total time=   0.1s
# [CV] END ..........................tfidfvectorizer__min_df=1; total time=   0.1s
# [CV] END ..........................tfidfvectorizer__min_df=3; total time=   0.1s
# [CV] END ..........................tfidfvectorizer__min_df=3; total time=   0.1s
# [CV] END ..........................tfidfvectorizer__min_df=3; total time=   0.1s
# [CV] END ..........................tfidfvectorizer__min_df=3; total time=   0.1s
# [CV] END ..........................tfidfvectorizer__min_df=3; total time=   0.1s
# [CV] END ..........................tfidfvectorizer__min_df=5; total time=   0.0s
# [CV] END ..........................tfidfvectorizer__min_df=5; total time=   0.1s
# [CV] END ..........................tfidfvectorizer__min_df=5; total time=   0.0s
# [CV] END ..........................tfidfvectorizer__min_df=5; total time=   0.1s
# [CV] END ..........................tfidfvectorizer__min_df=5; total time=   0.1s
# [CV] END .........................tfidfvectorizer__min_df=10; total time=   0.0s
# [CV] END .........................tfidfvectorizer__min_df=10; total time=   0.0s
# [CV] END .........................tfidfvectorizer__min_df=10; total time=   0.0s
# [CV] END .........................tfidfvectorizer__min_df=10; total time=   0.0s
# [CV] END .........................tfidfvectorizer__min_df=10; total time=   0.0s
# [CV] END .........................tfidfvectorizer__min_df=25; total time=   0.1s
# [CV] END .........................tfidfvectorizer__min_df=25; total time=   0.0s
# [CV] END .........................tfidfvectorizer__min_df=25; total time=   0.0s
# [CV] END .........................tfidfvectorizer__min_df=25; total time=   0.0s
# [CV] END .........................tfidfvectorizer__min_df=25; total time=   0.0s
# [CV] END ......................tfidfvectorizer__max_df=0.001; total time=   0.1s
# [CV] END ......................tfidfvectorizer__max_df=0.001; total time=   0.1s
# [CV] END ......................tfidfvectorizer__max_df=0.001; total time=   0.0s
# [CV] END ......................tfidfvectorizer__max_df=0.001; total time=   0.1s
# [CV] END ......................tfidfvectorizer__max_df=0.001; total time=   0.1s
# [CV] END .......................tfidfvectorizer__max_df=0.01; total time=   0.1s
# [CV] END .......................tfidfvectorizer__max_df=0.01; total time=   0.1s
# [CV] END .......................tfidfvectorizer__max_df=0.01; total time=   0.1s
# [CV] END .......................tfidfvectorizer__max_df=0.01; total time=   0.1s
# [CV] END .......................tfidfvectorizer__max_df=0.01; total time=   0.1s
# [CV] END ........................tfidfvectorizer__max_df=0.1; total time=   0.1s
# [CV] END ........................tfidfvectorizer__max_df=0.1; total time=   0.1s
# [CV] END ........................tfidfvectorizer__max_df=0.1; total time=   0.1s
# [CV] END ........................tfidfvectorizer__max_df=0.1; total time=   0.1s
# [CV] END ........................tfidfvectorizer__max_df=0.1; total time=   0.1s
# [CV] END ........................tfidfvectorizer__max_df=1.0; total time=   0.1s
# [CV] END ........................tfidfvectorizer__max_df=1.0; total time=   0.1s
# [CV] END ........................tfidfvectorizer__max_df=1.0; total time=   0.1s
# [CV] END ........................tfidfvectorizer__max_df=1.0; total time=   0.1s
# [CV] END ........................tfidfvectorizer__max_df=1.0; total time=   0.1s
# [CV] END .........................tfidfvectorizer__norm=None; total time=  12.5s
# [CV] END .........................tfidfvectorizer__norm=None; total time=  14.0s
# [CV] END .........................tfidfvectorizer__norm=None; total time=  13.8s
# [CV] END .........................tfidfvectorizer__norm=None; total time=  14.2s
# [CV] END .........................tfidfvectorizer__norm=None; total time=  12.7s
# [CV] END ...........................tfidfvectorizer__norm=l1; total time=   0.1s
# [CV] END ...........................tfidfvectorizer__norm=l1; total time=   0.1s
# [CV] END ...........................tfidfvectorizer__norm=l1; total time=   0.1s
# [CV] END ...........................tfidfvectorizer__norm=l1; total time=   0.1s
# [CV] END ...........................tfidfvectorizer__norm=l1; total time=   0.1s
# [CV] END ...........................tfidfvectorizer__norm=l2; total time=   0.1s
# [CV] END ...........................tfidfvectorizer__norm=l2; total time=   0.1s
# [CV] END ...........................tfidfvectorizer__norm=l2; total time=   0.1s
# [CV] END ...........................tfidfvectorizer__norm=l2; total time=   0.1s
# [CV] END ...........................tfidfvectorizer__norm=l2; total time=   0.1s
# [CV] END .................tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END .................tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END .................tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END .................tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END .................tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END ................tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END ................tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END ................tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END ................tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END ................tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END ..............................linearsvc__penalty=l1; total time=   0.2s
# [CV] END ..............................linearsvc__penalty=l1; total time=   0.2s
# [CV] END ..............................linearsvc__penalty=l1; total time=   0.3s
# [CV] END ..............................linearsvc__penalty=l1; total time=   0.2s
# [CV] END ..............................linearsvc__penalty=l1; total time=   0.2s
# [CV] END ..............................linearsvc__penalty=l2; total time=   0.1s
# [CV] END ..............................linearsvc__penalty=l2; total time=   0.1s
# [CV] END ..............................linearsvc__penalty=l2; total time=   0.1s
# [CV] END ..............................linearsvc__penalty=l2; total time=   0.1s
# [CV] END ..............................linearsvc__penalty=l2; total time=   0.1s
# [CV] END .................................linearsvc__C=0.001; total time=   0.0s
# [CV] END .................................linearsvc__C=0.001; total time=   0.0s
# [CV] END .................................linearsvc__C=0.001; total time=   0.0s
# [CV] END .................................linearsvc__C=0.001; total time=   0.0s
# [CV] END .................................linearsvc__C=0.001; total time=   0.0s
# [CV] END ..................................linearsvc__C=0.01; total time=   0.0s
# [CV] END ..................................linearsvc__C=0.01; total time=   0.0s
# [CV] END ..................................linearsvc__C=0.01; total time=   0.0s
# [CV] END ..................................linearsvc__C=0.01; total time=   0.0s
# [CV] END ..................................linearsvc__C=0.01; total time=   0.0s
# [CV] END ...................................linearsvc__C=0.1; total time=   0.0s
# [CV] END ...................................linearsvc__C=0.1; total time=   0.1s
# [CV] END ...................................linearsvc__C=0.1; total time=   0.0s
# [CV] END ...................................linearsvc__C=0.1; total time=   0.1s
# [CV] END ...................................linearsvc__C=0.1; total time=   0.1s
# [CV] END .....................................linearsvc__C=1; total time=   0.1s
# [CV] END .....................................linearsvc__C=1; total time=   0.1s
# [CV] END .....................................linearsvc__C=1; total time=   0.1s
# [CV] END .....................................linearsvc__C=1; total time=   0.1s
# [CV] END .....................................linearsvc__C=1; total time=   0.1s
# [CV] END ....................................linearsvc__C=10; total time=   0.3s
# [CV] END ....................................linearsvc__C=10; total time=   0.4s
# [CV] END ....................................linearsvc__C=10; total time=   0.3s
# [CV] END ....................................linearsvc__C=10; total time=   0.3s
# [CV] END ....................................linearsvc__C=10; total time=   0.3s
# [CV] END ...................................linearsvc__C=100; total time=   1.9s
# [CV] END ...................................linearsvc__C=100; total time=   2.0s
# [CV] END ...................................linearsvc__C=100; total time=   1.6s
# [CV] END ...................................linearsvc__C=100; total time=   1.8s
# [CV] END ...................................linearsvc__C=100; total time=   1.6s
# [CV] END ..................................linearsvc__C=1000; total time=   4.2s
# [CV] END ..................................linearsvc__C=1000; total time=   6.0s
# [CV] END ..................................linearsvc__C=1000; total time=   4.5s
# [CV] END ..................................linearsvc__C=1000; total time=   4.6s
# [CV] END ..................................linearsvc__C=1000; total time=   4.6s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.1; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.1; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.1; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.1; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.1; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=100; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=100; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=100; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=100; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=100; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000; total time=   0.1s
# [CV] END linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000; total time=   0.1s
# [CV] END .....................linearsvc__fit_intercept=False; total time=   0.1s
# [CV] END .....................linearsvc__fit_intercept=False; total time=   0.2s
# [CV] END .....................linearsvc__fit_intercept=False; total time=   0.1s
# [CV] END .....................linearsvc__fit_intercept=False; total time=   0.1s
# [CV] END .....................linearsvc__fit_intercept=False; total time=   0.1s
# [CV] END .......................linearsvc__class_weight=None; total time=   0.1s
# [CV] END .......................linearsvc__class_weight=None; total time=   0.1s
# [CV] END .......................linearsvc__class_weight=None; total time=   0.1s
# [CV] END .......................linearsvc__class_weight=None; total time=   0.1s
# [CV] END .......................linearsvc__class_weight=None; total time=   0.1s
# [CV] END ...................linearsvc__class_weight=balanced; total time=   0.1s
# [CV] END ...................linearsvc__class_weight=balanced; total time=   0.1s
# [CV] END ...................linearsvc__class_weight=balanced; total time=   0.1s
# [CV] END ...................linearsvc__class_weight=balanced; total time=   0.1s
# [CV] END ...................linearsvc__class_weight=balanced; total time=   0.1s

# %%
cv_results_df
# Out:
#    ngram_range min_df max_df  norm sublinear_tf penalty   tol      C  \
# 0       (1, 1)   None   None  None         None    None  None   None
# 1       (1, 2)   None   None  None         None    None  None   None
# 2       (2, 2)   None   None  None         None    None  None   None
# 3       (1, 3)   None   None  None         None    None  None   None
# 4       (2, 3)   None   None  None         None    None  None   None
# 5       (3, 3)   None   None  None         None    None  None   None
# 6         None      1   None  None         None    None  None   None
# 7         None      3   None  None         None    None  None   None
# 8         None      5   None  None         None    None  None   None
# 9         None     10   None  None         None    None  None   None
# 10        None     25   None  None         None    None  None   None
# 11        None   None  0.001  None         None    None  None   None
# 12        None   None   0.01  None         None    None  None   None
# 13        None   None    0.1  None         None    None  None   None
# 14        None   None    1.0  None         None    None  None   None
# 15        None   None   None  None         None    None  None   None
# 16        None   None   None    l1         None    None  None   None
# 17        None   None   None    l2         None    None  None   None
# 18        None   None   None  None         True    None  None   None
# 19        None   None   None  None        False    None  None   None
# 20        None   None   None  None         None      l1  None   None
# 21        None   None   None  None         None      l2  None   None
# 22        None   None   None  None         None    None  None  0.001
# 23        None   None   None  None         None    None  None   0.01
# 24        None   None   None  None         None    None  None    0.1
# 25        None   None   None  None         None    None  None      1
# 26        None   None   None  None         None    None  None     10
# 27        None   None   None  None         None    None  None    100
# 28        None   None   None  None         None    None  None   1000
# 29        None   None   None  None         None    None  None   None
# 30        None   None   None  None         None    None  None   None
# 31        None   None   None  None         None    None  None   None
# 32        None   None   None  None         None    None  None   None
# 33        None   None   None  None         None    None  None   None
# 34        None   None   None  None         None    None  None   None
# 35        None   None   None  None         None    None  None   None
# 36        None   None   None  None         None    None  None   None
# 37        None   None   None  None         None    None  None   None
# 38        None   None   None  None         None    None  None   None
#
#    fit_intercept intercept_scaling class_weight  split0_test_score  \
# 0           None              None         None           0.601934
# 1           None              None         None           0.617502
# 2           None              None         None           0.165468
# 3           None              None         None           0.618792
# 4           None              None         None           0.168206
# 5           None              None         None           0.050884
# 6           None              None         None           0.601934
# 7           None              None         None           0.591653
# 8           None              None         None           0.602883
# 9           None              None         None           0.596422
# 10          None              None         None           0.527480
# 11          None              None         None           0.093277
# 12          None              None         None           0.479637
# 13          None              None         None           0.601934
# 14          None              None         None           0.601934
# 15          None              None         None           0.485442
# 16          None              None         None           0.611494
# 17          None              None         None           0.601934
# 18          None              None         None           0.603857
# 19          None              None         None           0.601934
# 20          None              None         None           0.617355
# 21          None              None         None           0.601934
# 22          None              None         None           0.412155
# 23          None              None         None           0.601942
# 24          None              None         None           0.624612
# 25          None              None         None           0.601934
# 26          None              None         None           0.522791
# 27          None              None         None           0.465726
# 28          None              None         None           0.435771
# 29          True             0.001         None           0.596601
# 30          True              0.01         None           0.595479
# 31          True               0.1         None           0.600468
# 32          True                 1         None           0.601934
# 33          True                10         None           0.601934
# 34          True               100         None           0.599856
# 35          True              1000         None           0.601193
# 36         False              None         None           0.591933
# 37          None              None         None           0.595156
# 38          None              None     balanced           0.601934
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.599224           0.598257           0.602419
# 1            0.619286           0.612693           0.629683
# 2            0.165107           0.160780           0.151540
# 3            0.617633           0.610566           0.629861
# 4            0.166085           0.158762           0.149691
# 5            0.046324           0.029242           0.006440
# 6            0.599224           0.598257           0.602419
# 7            0.601493           0.600736           0.601016
# 8            0.605923           0.603020           0.604719
# 9            0.582668           0.592378           0.587082
# 10           0.531846           0.543311           0.536686
# 11           0.100359           0.090441           0.094609
# 12           0.481287           0.470399           0.483538
# 13           0.599224           0.598257           0.602419
# 14           0.599224           0.598257           0.602419
# 15           0.510178           0.490396           0.492119
# 16           0.607460           0.618419           0.622746
# 17           0.599224           0.598257           0.602419
# 18           0.601039           0.600709           0.606488
# 19           0.599224           0.598257           0.602419
# 20           0.627901           0.624106           0.631876
# 21           0.599224           0.598257           0.602419
# 22           0.390465           0.402385           0.416919
# 23           0.595775           0.608077           0.611867
# 24           0.624413           0.633349           0.643372
# 25           0.599224           0.598257           0.602419
# 26           0.519320           0.522856           0.529940
# 27           0.474202           0.474174           0.473304
# 28           0.460527           0.440409           0.446686
# 29           0.601370           0.605480           0.599369
# 30           0.599191           0.604880           0.599648
# 31           0.601808           0.600702           0.602606
# 32           0.599224           0.598257           0.602419
# 33           0.599700           0.599123           0.601536
# 34           0.602875           0.601024           0.600790
# 35           0.580140           0.585825           0.606233
# 36           0.597623           0.599905           0.596965
# 37           0.595823           0.597818           0.595491
# 38           0.599224           0.598257           0.602419
#
#     split4_test_score  mean_test_score  mean_fit_time  rank_test_score
# 0            0.611532         0.602673       0.219851               12
# 1            0.631827         0.622198       0.697648                4
# 2            0.188462         0.166271       0.584062               36
# 3            0.635524         0.622475       0.654165                3
# 4            0.166421         0.161833       0.400776               37
# 5            0.043270         0.035232       0.231010               39
# 6            0.611532         0.602673       0.213691               12
# 7            0.610980         0.601176       0.139511               24
# 8            0.616016         0.606512       0.138220                6
# 9            0.599255         0.591561       0.128613               28
# 10           0.537607         0.535386       0.127169               29
# 11           0.098473         0.095432       0.151697               38
# 12           0.484335         0.479839       0.201612               32
# 13           0.611532         0.602673       0.219428               12
# 14           0.611532         0.602673       0.211605               12
# 15           0.508825         0.497392      13.518400               31
# 16           0.618454         0.615715       0.187255                5
# 17           0.611532         0.602673       0.203691               12
# 18           0.611814         0.604781       0.203313                8
# 19           0.611532         0.602673       0.216318               12
# 20           0.639292         0.628106       0.329767                2
# 21           0.611532         0.602673       0.206203               12
# 22           0.404976         0.405380       0.080256               35
# 23           0.607357         0.605004       0.098053                7
# 24           0.642834         0.633716       0.140379                1
# 25           0.611532         0.602673       0.188026               12
# 26           0.539628         0.526907       0.432030               30
# 27           0.480016         0.473484       1.876296               33
# 28           0.469044         0.450488       4.880783               34
# 29           0.606159         0.601796       0.201568               22
# 30           0.607503         0.601340       0.208982               23
# 31           0.613911         0.603899       0.193046                9
# 32           0.611532         0.602673       0.199423               12
# 33           0.611891         0.602837       0.219815               11
# 34           0.611872         0.603283       0.195030               10
# 35           0.614501         0.597579       0.153214               27
# 36           0.602168         0.597719       0.216578               26
# 37           0.604991         0.597856       0.190201               25
# 38           0.611532         0.602673       0.203345               12

# %%
from datetime import timedelta

print(f'Fitted {randomized_search.n_splits_} folds of {len(cv_results_df)} candidates, finished in {str(timedelta(seconds=estimation))}.')
print(f"Best score: {randomized_search.best_score_}")
print("Best hyper-parameters:")
randomized_search.best_params_
# Out:
# Fitted 5 folds of 39 candidates, finished in 0:02:27.616682.
# Best score: 0.6337162376913333
# Best hyper-parameters:
# {'linearsvc__C': 0.1}

# %%
for name, values in [
    ("ngram_range", [(1, 1), (1, 2), (2, 2), (1, 3), (2, 3), (3, 3)]),
    ("min_df", [1, 3, 5, 10, 25]),
    ("max_df", [0.001, 0.01, 0.1, 1.0]),
]:
    for value in values:
        classification_pipeline.named_steps["tfidfvectorizer"].set_params(**tfidfvectorizer_hyperparameters)
        classification_pipeline.named_steps["tfidfvectorizer"].set_params(**{name: value})
        classification_pipeline.fit(X_train, y_train)
        print(name, value, len(classification_pipeline.named_steps["tfidfvectorizer"].vocabulary_))
# Out:
# ngram_range (1, 1) 8058
# ngram_range (1, 2) 58121
# ngram_range (2, 2) 50063
# ngram_range (1, 3) 105068
# ngram_range (2, 3) 97010
# ngram_range (3, 3) 46947
# min_df 1 8058
# min_df 3 3004
# min_df 5 2067
# min_df 10 1236
# min_df 25 576
# max_df 0.001 7168
# max_df 0.01 7986
# max_df 0.1 8058
# max_df 1.0 8058
