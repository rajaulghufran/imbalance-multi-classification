# %% [markdown]
# ---

# %%
from pathlib import Path

path = Path().absolute()

# %%
cd ../
# Out:
# c:\Users\c10nGp4\OneDrive\Documents\GitHub\imbalance-multi-classification

# %%
import time

from sklearn.pipeline import Pipeline

# %% [markdown]
# ---

# %% [markdown]
# ### Load Data
# ---

# %%
import pandas as pd

# Load dataset
training_set_df = pd.read_csv(path / "assets/datasets/training-set-1.csv", delimiter=";")

# Get X and y from dataset
X_train = list(training_set_df["texts"])
y_train = list(training_set_df["targets"])

# %% [markdown]
# ### Data Preparation
# ---

# %% [markdown]
# #### Text Preprocessing

# %%
from pipeline.text_cleaning import TextCleaning
from pipeline.tokenize_mwt_pos_lemma import TokenizeMWTPOSLemma

text_preprocessing_pipeline: Pipeline = Pipeline([
    ("text_cleaning", TextCleaning()),
    ("tokenize_mwt_pos_lemma", TokenizeMWTPOSLemma())
])

X_train = text_preprocessing_pipeline.transform(X_train)
# Out:
# 2023-06-12 06:52:13 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# 2023-06-12 06:52:13 INFO: DOWNLOAD STANZA MODEL
# 2023-06-12 06:52:13 INFO: LOAD STANZA PIPELINE: tokenize,mwt,pos,lemma
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.5.0.json:   0%|   …
# 2023-06-12 06:52:13 INFO: Loading these models for language: id (Indonesian):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | gsd     |
# | mwt       | gsd     |
# | pos       | gsd     |
# | lemma     | gsd     |
# =======================
#
# 2023-06-12 06:52:13 INFO: Using device: cuda
# 2023-06-12 06:52:13 INFO: Loading: tokenize
# 2023-06-12 06:52:16 INFO: Loading: mwt
# 2023-06-12 06:52:16 INFO: Loading: pos
# 2023-06-12 06:52:16 INFO: Loading: lemma
# 2023-06-12 06:52:16 INFO: Done loading processors!
# 2023-06-12 06:52:16 INFO: TEXT CLEANING
# 2023-06-12 06:52:18 INFO: TOKENIZE, MWT, POS, LEMMA

# %% [markdown]
# #### Feature Selection

# %%
from pipeline.data.stopwords import STOPWORDS
from pipeline.pos_filter import POSFilter
from pipeline.stopword_removal import StopWordRemoval
from pipeline.document_transformer import DocumentTransformer

pos_filter_hyperparameters = {
    "pos": ("ADJ","ADV","NOUN","PART","VERB")
}

stopword_removal_hyperparameters = {
    "stopwords": STOPWORDS
}

document_transformer_hyperparameters = {
    "feat_attrs": ["lemma","upos"]
}

feature_selection_pipeline: Pipeline = Pipeline([
    ("pos_filter", POSFilter(**pos_filter_hyperparameters, verbose=0)),
    ("stopword_removal", StopWordRemoval(**stopword_removal_hyperparameters, verbose=0)),
    ("document_transformer", DocumentTransformer(**document_transformer_hyperparameters, verbose=0))
])

X_train = feature_selection_pipeline.transform(X_train)

# %% [markdown]
# ### Hyper-parameters tuning
# ---

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC

def fun(arg):
    return arg

tfidfvectorizer_hyperparameters = {
    "encoding": "ascii",
    "decode_error": "ignore",
    "strip_accents": "ascii",
    "preprocessor": fun,
    "tokenizer": fun,
    "analyzer": "word",
    "token_pattern": None
}

linearsvc_hyperparameters = {
    "loss": "squared_hinge",
    "dual": False,
    "tol": 0.0001,
    "multi_class": "ovr",
    "max_iter": 1000000,
    "random_state": 42
}

classification_pipeline: Pipeline = Pipeline([
    ("tfidfvectorizer", TfidfVectorizer(**tfidfvectorizer_hyperparameters)),
    ("linearsvc", LinearSVC(**linearsvc_hyperparameters))
])

# %%
import warnings

from sklearn.exceptions import ConvergenceWarning
from sklearn.metrics import make_scorer, accuracy_score, matthews_corrcoef
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedShuffleSplit

warnings.filterwarnings("ignore", category=ConvergenceWarning)
# warnings.filterwarnings("default", category=ConvergenceWarning)

param_distributions = [
    {
        "tfidfvectorizer__ngram_range": ((1, 1),  (1, 2), (2, 2), (1, 3),  (2, 3), (3, 3)),
        "tfidfvectorizer__min_df": (1, 3, 5, 10, 25),
        "tfidfvectorizer__max_df": (0.001, 0.01, 0.1, 1.0),
        "tfidfvectorizer__norm": (None, "l1", "l2"),
        "tfidfvectorizer__sublinear_tf": (True, False),
        "linearsvc__penalty": ("l1", "l2"),
        "linearsvc__C": (0.001, 0.01, 0.1, 1, 10, 100, 1000),
        "linearsvc__fit_intercept": (True,),
        "linearsvc__intercept_scaling": (0.001, 0.01, 0.1, 1, 10, 100, 1000),
        "linearsvc__class_weight": (None, "balanced"),
    },
    {
        "tfidfvectorizer__ngram_range": ((1, 1),  (1, 2), (2, 2), (1, 3),  (2, 3), (3, 3)),
        "tfidfvectorizer__min_df": (1, 3, 5, 10, 25),
        "tfidfvectorizer__max_df": (0.001, 0.01, 0.1, 1.0),
        "tfidfvectorizer__norm": (None, "l1", "l2"),
        "tfidfvectorizer__sublinear_tf": (True, False),
        "linearsvc__penalty": ("l1", "l2"),
        "linearsvc__C": (0.001, 0.01, 0.1, 1, 10, 100, 1000),
        "linearsvc__fit_intercept": (False,),
        "linearsvc__class_weight": (None, "balanced"),
    },
]

n_iter = 200
n_splits = 5
train_size = 0.8
n_jobs = 1
verbose = 2

randomized_search = RandomizedSearchCV(
    estimator=classification_pipeline,
    param_distributions=param_distributions,
    n_iter=n_iter,
    scoring=make_scorer(matthews_corrcoef),
    n_jobs=n_jobs,
    cv=StratifiedShuffleSplit(n_splits=n_splits, train_size=train_size, random_state=42),
    verbose=verbose,
    random_state=42
)

t0 = time.time()
randomized_search.fit(X_train, y_train)
estimation = time.time() - t0

cv_results_df = pd.DataFrame(randomized_search.cv_results_)
cv_results_df = cv_results_df.rename(lambda col_name: col_name.split("__")[-1] if "param_" in col_name else col_name, axis="columns")

col_names = [
    "ngram_range","min_df","max_df","norm","sublinear_tf",
    "penalty","C","fit_intercept","intercept_scaling","class_weight",
    "split0_test_score","split1_test_score","split2_test_score","split3_test_score","split4_test_score","mean_test_score",
    "mean_fit_time",
    "rank_test_score"
]

cv_results_df = cv_results_df.reindex(columns=col_names)
cv_results_df = cv_results_df.fillna("None")
cv_results_df.to_csv(path / "assets/experiments/experiment_1_cv_results.csv", sep=";", index=False)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(2, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=True; total time=   4.4s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(2, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=True; total time=   4.6s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(2, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=True; total time=   4.7s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(2, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=True; total time=   4.1s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(2, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=True; total time=   4.7s
# [CV] END linearsvc__C=0.01, linearsvc__class_weight=balanced, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.2s
# [CV] END linearsvc__C=0.01, linearsvc__class_weight=balanced, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.2s
# [CV] END linearsvc__C=0.01, linearsvc__class_weight=balanced, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.2s
# [CV] END linearsvc__C=0.01, linearsvc__class_weight=balanced, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.2s
# [CV] END linearsvc__C=0.01, linearsvc__class_weight=balanced, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.2s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(2, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(2, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(2, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(2, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(2, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=True; total time=   2.4s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=True; total time=   2.4s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=True; total time=   2.3s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=True; total time=   2.3s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=True; total time=   2.3s
# [CV] END linearsvc__C=100, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END linearsvc__C=100, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END linearsvc__C=100, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END linearsvc__C=100, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END linearsvc__C=100, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END linearsvc__C=0.1, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END linearsvc__C=0.1, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END linearsvc__C=0.1, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END linearsvc__C=0.1, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END linearsvc__C=0.1, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END linearsvc__C=10, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   5.2s
# [CV] END linearsvc__C=10, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   5.6s
# [CV] END linearsvc__C=10, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   5.5s
# [CV] END linearsvc__C=10, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   6.1s
# [CV] END linearsvc__C=10, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   5.4s
# [CV] END linearsvc__C=100, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=  19.6s
# [CV] END linearsvc__C=100, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=  19.0s
# [CV] END linearsvc__C=100, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=  20.2s
# [CV] END linearsvc__C=100, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=  19.9s
# [CV] END linearsvc__C=100, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=  19.2s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   0.2s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   0.2s
# [CV] END linearsvc__C=0.001, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END linearsvc__C=0.001, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END linearsvc__C=0.001, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END linearsvc__C=0.001, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END linearsvc__C=0.001, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END linearsvc__C=0.1, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END linearsvc__C=0.1, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END linearsvc__C=0.1, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END linearsvc__C=0.1, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END linearsvc__C=0.1, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END linearsvc__C=1, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.2s
# [CV] END linearsvc__C=1, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.2s
# [CV] END linearsvc__C=1, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.2s
# [CV] END linearsvc__C=1, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.2s
# [CV] END linearsvc__C=1, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=10, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.2s
# [CV] END linearsvc__C=1, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=True; total time=   0.4s
# [CV] END linearsvc__C=1, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=True; total time=   0.3s
# [CV] END linearsvc__C=1, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=True; total time=   0.4s
# [CV] END linearsvc__C=1, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=True; total time=   0.4s
# [CV] END linearsvc__C=1, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=True; total time=   0.5s
# [CV] END linearsvc__C=0.001, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=0.001, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=0.001, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=0.001, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=0.001, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.001, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=0.1, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l1, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=0.1, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l1, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=0.1, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l1, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=0.1, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l1, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=0.1, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l1, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=1, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=1, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=1, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=1, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=1, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=0.001, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=False; total time=   0.3s
# [CV] END linearsvc__C=0.001, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=False; total time=   0.2s
# [CV] END linearsvc__C=0.001, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=False; total time=   0.2s
# [CV] END linearsvc__C=0.001, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=False; total time=   0.2s
# [CV] END linearsvc__C=0.001, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=False; total time=   0.2s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   1.5s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   1.7s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   1.3s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   1.6s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   1.4s
# [CV] END linearsvc__C=10, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.3s
# [CV] END linearsvc__C=10, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.3s
# [CV] END linearsvc__C=10, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.3s
# [CV] END linearsvc__C=10, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.3s
# [CV] END linearsvc__C=10, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.3s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   0.1s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   0.7s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   0.6s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   0.6s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   0.7s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   0.6s
# [CV] END linearsvc__C=10, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.1, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   0.4s
# [CV] END linearsvc__C=10, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.1, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   0.4s
# [CV] END linearsvc__C=10, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.1, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   0.4s
# [CV] END linearsvc__C=10, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.1, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   0.3s
# [CV] END linearsvc__C=10, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.1, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   0.4s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(2, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(2, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(2, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(2, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=10, tfidfvectorizer__ngram_range=(2, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=0.1, linearsvc__class_weight=balanced, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END linearsvc__C=0.1, linearsvc__class_weight=balanced, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END linearsvc__C=0.1, linearsvc__class_weight=balanced, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END linearsvc__C=0.1, linearsvc__class_weight=balanced, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END linearsvc__C=0.1, linearsvc__class_weight=balanced, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(3, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.7s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.7s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.8s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.8s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.7s
# [CV] END linearsvc__C=0.001, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l2, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=0.001, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l2, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=0.001, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l2, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=0.001, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l2, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=0.001, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l2, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=3, tfidfvectorizer__ngram_range=(1, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   7.5s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   6.9s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   6.7s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   7.3s
# [CV] END linearsvc__C=1000, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.1, linearsvc__penalty=l1, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   7.9s
# ...
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l1, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(2, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l1, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=5, tfidfvectorizer__ngram_range=(2, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=True; total time=   0.0s
# [CV] END linearsvc__C=1, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l2, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=False; total time=   0.2s
# [CV] END linearsvc__C=1, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l2, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=False; total time=   0.2s
# [CV] END linearsvc__C=1, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l2, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=False; total time=   0.2s
# [CV] END linearsvc__C=1, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l2, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=False; total time=   0.2s
# [CV] END linearsvc__C=1, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1000, linearsvc__penalty=l2, tfidfvectorizer__max_df=1.0, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=False; total time=   0.1s
# [CV] END linearsvc__C=0.01, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(2, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END linearsvc__C=0.01, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(2, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END linearsvc__C=0.01, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(2, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END linearsvc__C=0.01, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(2, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END linearsvc__C=0.01, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.01, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(2, 3), tfidfvectorizer__norm=l1, tfidfvectorizer__sublinear_tf=False; total time=   0.0s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   2.4s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   2.3s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   2.5s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   2.9s
# [CV] END linearsvc__C=100, linearsvc__class_weight=None, linearsvc__fit_intercept=False, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.001, tfidfvectorizer__min_df=1, tfidfvectorizer__ngram_range=(2, 2), tfidfvectorizer__norm=l2, tfidfvectorizer__sublinear_tf=True; total time=   2.6s
# [CV] END linearsvc__C=10, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   4.7s
# [CV] END linearsvc__C=10, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   4.9s
# [CV] END linearsvc__C=10, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   3.9s
# [CV] END linearsvc__C=10, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   4.2s
# [CV] END linearsvc__C=10, linearsvc__class_weight=balanced, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=0.01, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 1), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   6.4s
# [CV] END linearsvc__C=10, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   0.5s
# [CV] END linearsvc__C=10, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   0.4s
# [CV] END linearsvc__C=10, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   0.4s
# [CV] END linearsvc__C=10, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   0.5s
# [CV] END linearsvc__C=10, linearsvc__class_weight=None, linearsvc__fit_intercept=True, linearsvc__intercept_scaling=1, linearsvc__penalty=l2, tfidfvectorizer__max_df=0.1, tfidfvectorizer__min_df=25, tfidfvectorizer__ngram_range=(1, 3), tfidfvectorizer__norm=None, tfidfvectorizer__sublinear_tf=True; total time=   0.5s
# c:\Users\c10nGp4\anaconda3\envs\imbalance-multi-classification\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 72 fits failed out of a total of 1000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 70 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\c10nGp4\anaconda3\envs\imbalance-multi-classification\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\c10nGp4\anaconda3\envs\imbalance-multi-classification\lib\site-packages\sklearn\pipeline.py", line 401, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\Users\c10nGp4\anaconda3\envs\imbalance-multi-classification\lib\site-packages\sklearn\pipeline.py", line 359, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "c:\Users\c10nGp4\anaconda3\envs\imbalance-multi-classification\lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\Users\c10nGp4\anaconda3\envs\imbalance-multi-classification\lib\site-packages\sklearn\pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\Users\c10nGp4\anaconda3\envs\imbalance-multi-classification\lib\site-packages\sklearn\feature_extraction\text.py", line 2133, in fit_transform
#     X = super().fit_transform(raw_documents)
#   File "c:\Users\c10nGp4\anaconda3\envs\imbalance-multi-classification\lib\site-packages\sklearn\feature_extraction\text.py", line 1398, in fit_transform
#     raise ValueError("max_df corresponds to < documents than min_df")
# ValueError: max_df corresponds to < documents than min_df
#
# --------------------------------------------------------------------------------
# 2 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\c10nGp4\anaconda3\envs\imbalance-multi-classification\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\c10nGp4\anaconda3\envs\imbalance-multi-classification\lib\site-packages\sklearn\pipeline.py", line 401, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#   File "c:\Users\c10nGp4\anaconda3\envs\imbalance-multi-classification\lib\site-packages\sklearn\pipeline.py", line 359, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#   File "c:\Users\c10nGp4\anaconda3\envs\imbalance-multi-classification\lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#   File "c:\Users\c10nGp4\anaconda3\envs\imbalance-multi-classification\lib\site-packages\sklearn\pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#   File "c:\Users\c10nGp4\anaconda3\envs\imbalance-multi-classification\lib\site-packages\sklearn\feature_extraction\text.py", line 2133, in fit_transform
#     X = super().fit_transform(raw_documents)
#   File "c:\Users\c10nGp4\anaconda3\envs\imbalance-multi-classification\lib\site-packages\sklearn\feature_extraction\text.py", line 1401, in fit_transform
#     X, self.stop_words_ = self._limit_features(
#   File "c:\Users\c10nGp4\anaconda3\envs\imbalance-multi-classification\lib\site-packages\sklearn\feature_extraction\text.py", line 1253, in _limit_features
#     raise ValueError(
# ValueError: After pruning, no terms remain. Try a lower min_df or a higher max_df.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\c10nGp4\anaconda3\envs\imbalance-multi-classification\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [ 6.93465304e-02  5.27084080e-01             nan  1.18047199e-01
#   1.54273149e-03  4.88525066e-02             nan  1.54273149e-03
#   5.56877955e-01  4.55111934e-01  4.23129541e-01  0.00000000e+00
#   4.84080649e-02  4.96696555e-01  1.39013018e-01  4.57321265e-02
#   5.54357900e-01  1.75509338e-02  5.25376721e-01  3.51388121e-02
#   4.22124477e-01 -4.35924564e-03  4.80821007e-01  5.55692317e-01
#   4.48105346e-01  1.74525838e-02 -9.71581456e-04  4.98984407e-01
#   4.99037924e-01  1.20729664e-01  1.46485066e-01  5.17939063e-01
#   4.74753827e-01  5.82144046e-01  5.70915523e-01  1.69693372e-01
#   6.40093443e-01  7.90214983e-02  4.47193673e-01  6.31808046e-01
#   5.32431818e-01  2.94372400e-01  1.55426672e-01  1.50270959e-01
#   0.00000000e+00             nan             nan  5.83117599e-01
#   4.63267550e-01  5.59706875e-01  5.50097642e-01  5.54038802e-02
#   6.58659185e-02  4.14858611e-01  0.00000000e+00  5.40739852e-01
#              nan  6.81076927e-02  0.00000000e+00  5.92639756e-01
#   6.22008594e-01  2.19402710e-01  4.20269237e-01  5.71942214e-01
#   0.00000000e+00  8.20808333e-02  5.61088299e-01  4.72678195e-01
#              nan  0.00000000e+00  5.95310983e-01 -5.08337235e-03
#   0.00000000e+00  5.14394875e-01  0.00000000e+00 -5.46284478e-04
#   7.58453778e-02  8.75892519e-02  4.26033419e-01  1.15940291e-01
#   5.78611528e-01  8.46403247e-02  5.09059720e-01  1.60630310e-01
#  -4.35124964e-03  4.87468997e-03  9.57101579e-02  4.95740619e-01
#   5.96471152e-01  5.50824241e-01  3.20456539e-03 -2.08967968e-03
#   6.88854470e-02  2.25083338e-02  8.94218809e-02  2.87800179e-02
#   4.25456260e-01  2.81592606e-01  4.62475093e-01  6.68205159e-02
#   5.75191250e-01  3.41263240e-02  9.12096873e-02  7.58453778e-02
#   4.11996059e-01  1.44663227e-01             nan  0.00000000e+00
#   3.09752732e-03  3.47097403e-02  4.23143949e-01  5.46450479e-01
#              nan -3.96060501e-07  3.71676439e-02  4.45474925e-01
#   5.66517470e-01  1.66311610e-01  3.74105044e-01  1.45863550e-01
#   6.25189707e-01  4.18025066e-01  4.42149829e-01 -5.90909565e-03
#   5.46033360e-01  2.86066866e-02             nan  9.21808954e-02
#   5.41513072e-01  3.02131989e-02  5.29845139e-01  8.12066034e-02
#   1.44003755e-01  1.41175602e-01  5.37290204e-01  5.38477529e-01
#   4.93740349e-02  5.92609654e-02  4.22769953e-01  1.17737568e-01
#   6.01821412e-02  6.06900793e-02  7.86574862e-02             nan
#   5.89970382e-01  6.94825981e-02  4.27897415e-01  1.57868037e-01
#   6.90673124e-02  7.06960924e-02  4.18312016e-01  4.08761391e-01
#   8.88981309e-02  5.38954974e-01  5.02649154e-01             nan
#   0.00000000e+00  5.32271276e-01  8.05194281e-02             nan
#   0.00000000e+00  4.13510072e-01  8.57034181e-02  8.16007511e-02
#   3.29581024e-03  5.97879058e-01  5.82587175e-01  7.89577475e-02
#   2.92679418e-01             nan  5.54038802e-02  5.41857655e-01
#   3.36610886e-02  1.58569828e-01  3.07275112e-02  1.54273149e-03
#   4.98461108e-01             nan  3.39442855e-02  0.00000000e+00
#   1.01786437e-01  7.38855991e-02  1.44063754e-01  7.17168228e-02
#   0.00000000e+00  5.17207311e-01  4.69852164e-01  1.93942737e-03
#   5.71401350e-02             nan  5.71357591e-01  8.92641894e-02
#   6.55688260e-02             nan  7.11146365e-02  5.33821260e-01
#   5.98316717e-02  1.20338727e-01  5.32649244e-01  5.40829884e-01]
#   warnings.warn(

# %%
cv_results_df
# Out:
#     ngram_range  min_df  max_df  norm  sublinear_tf penalty        C  \
# 0        (2, 3)       5   0.010    l1          True      l2  1000.00
# 1        (1, 3)      25   1.000    l2         False      l2     0.01
# 2        (2, 3)      25   0.001    l2          True      l2  1000.00
# 3        (2, 2)       1   0.001    l1          True      l1   100.00
# 4        (3, 3)      25   0.010    l2         False      l1   100.00
# ..          ...     ...     ...   ...           ...     ...      ...
# 195      (1, 3)      25   1.000  None         False      l2     1.00
# 196      (2, 3)      25   0.010    l1         False      l2     0.01
# 197      (2, 2)       1   0.001    l2          True      l2   100.00
# 198      (1, 1)      25   0.100  None          True      l2    10.00
# 199      (1, 3)      25   0.100  None          True      l2    10.00
#
#      fit_intercept intercept_scaling class_weight split0_test_score  \
# 0             True             0.001         None          0.073749
# 1            False              None     balanced          0.528253
# 2             True             0.001     balanced              None
# 3             True               0.1         None          0.138052
# 4             True              1000     balanced          0.000834
# ..             ...               ...          ...               ...
# 195           True              1000     balanced          0.530497
# 196           True              0.01         None          0.047227
# 197          False              None         None          0.120888
# 198           True              0.01     balanced          0.527736
# 199           True                 1         None          0.527994
#
#     split1_test_score split2_test_score split3_test_score split4_test_score  \
# 0             0.08011          0.071846          0.041351          0.079678
# 1            0.517243          0.534561          0.531816          0.523547
# 2                None              None              None              None
# 3            0.113176           0.11629           0.10113          0.121588
# 4           -0.001632          0.021144         -0.005404         -0.007229
# ..                ...               ...               ...               ...
# 195          0.534157          0.539728          0.533884          0.530841
# 196          0.072866          0.080138          0.037986          0.060941
# 197          0.127675          0.108786          0.121595           0.12275
# 198          0.531907          0.535517          0.541849          0.526237
# 199          0.533061          0.553922          0.542142          0.547031
#
#     mean_test_score  mean_fit_time  rank_test_score
# 0          0.069347       4.568763              125
# 1          0.527084       0.281454               40
# 2              None       0.134429              185
# 3          0.118047       2.411102               98
# 4          0.001543       0.123117              161
# ..              ...            ...              ...
# 195        0.533821       0.232899               35
# 196        0.059832       0.106526              134
# 197        0.120339       2.614573               97
# 198        0.532649       4.928613               36
# 199         0.54083       0.519781               30
#
# [200 rows x 18 columns]

# %%
from datetime import timedelta

print(f'Fitted {randomized_search.n_splits_} folds of {len(cv_results_df)} candidates, finished in {str(timedelta(seconds=estimation))}.')
print(f"Best score: {randomized_search.best_score_}")
print("Best hyper-parameters:")
randomized_search.best_params_
# Out:
# Fitted 5 folds of 200 candidates, finished in 1:20:13.142074.
# Best score: 0.6400934433728541
# Best hyper-parameters:
# {'tfidfvectorizer__sublinear_tf': False,
#  'tfidfvectorizer__norm': 'l2',
#  'tfidfvectorizer__ngram_range': (1, 3),
#  'tfidfvectorizer__min_df': 1,
#  'tfidfvectorizer__max_df': 1.0,
#  'linearsvc__penalty': 'l1',
#  'linearsvc__intercept_scaling': 10,
#  'linearsvc__fit_intercept': True,
#  'linearsvc__class_weight': None,
#  'linearsvc__C': 1}
